# %% [markdown]
# # **Students Who Slip On Maths**

# %% [markdown]
# ## Objectives
#
# * Import the inital .csv file to a pandas dataframe for inspection
#
# * Diagnose and make any necessary Transformations
#
# * Engineer any features that may be needed or useful
#
# * Cement the made changes into a new dataframe to be exported  to a new .csv
#
#
# ## Inputs
#
# * The inital 'student_mat.csv'
#
# * Libraires containing the tools needed, pandas, numpy, matplotlib, seaborn.
#
# * A HelperFuncs.py with helper functions
#
# ## Outputs
#
# * A worked dataframe, exported to a .csv

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\NateM\\Desktop\\CI_DA\\Capstone_Three\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\NateM\\Desktop\\CI_DA\\Capstone_Three'

# %% [markdown]
# # Import block

# %%
# Libraries needed 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# Helper function
from HelperFuncs import InitialInspect

# %% [markdown]
# ---

# %% [markdown]
# # Section 1 - Load

# %% [markdown]
# Load the raw .csv into a pandas dataframe

# %%
# Load the raw data
df_raw = pd.read_csv("Dataset/Raw/student_mat.csv", sep=";")

# View the dataframe
df_raw.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# Now to use the InitialInspect helper function to get the first look at the data

# %%
# Helper function
InitialInspect(df_raw)
# Out:
# Initial shape: (Row x Col) (395, 33)
# ...
# Columns data types:
#  school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object
# ...
# Missing value counts:
# school: 0.
# sex: 0.
# age: 0.
# address: 0.
# famsize: 0.
# Pstatus: 0.
# Medu: 0.
# Fedu: 0.
# Mjob: 0.
# Fjob: 0.
# reason: 0.
# ...

# %% [markdown]
# This summary shows that we have 395 rows and 33 columns. The datatypes all appear to be in order with no datetime infromation to handle. We already know there are no missing values from the dataset source and our massive amounts of duplicates is due to the nature of the information; being ranges or categories.
#
# The .describe() summary shows that out important values like absences and final grade (G3) have no out of range errors which means we're not going to need any filtering or imputing, at least not right now.

# %% [markdown]
# With no cleaning needed to be done. We can move on to the transformations

# %% [markdown]
# ---

# %% [markdown]
# # Section 2 - Transformations

# %% [markdown]
# As the dataset is quite clean, there's only going to be a couple transformations.

# %% [markdown]
# Firstly we'll make a 'studytime_label' column. As 'studytime' is in bins of 1-4, we'll apply that label into the dataset so that information can be seen.

# %%
# Applying the new column
df_raw["studytime_label"] = df_raw["studytime"].map({
    1: "< 2 hours",
    2: "2 - 5 hours",
    3: "5 - 10 hours",
    4: "> 10 hours"
})

# Inspect the new column
df_raw.head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1   at_home     other
# 2     GP   F   15       U     LE3       T     1     1   at_home     other
# 3     GP   F   15       U     GT3       T     4     2    health  services
# 4     GP   F   16       U     GT3       T     3     3     other     other
# 5     GP   M   16       U     LE3       T     4     3  services     other
# 6     GP   M   16       U     LE3       T     2     2     other     other
# 7     GP   F   17       U     GT3       A     4     4     other   teacher
# 8     GP   M   15       U     LE3       A     3     2  services     other
# 9     GP   M   15       U     GT3       T     3     4     other     other
#
#    ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 studytime_label
# ...

# %% [markdown]
# Secondly, a handful of columns contain personal information that

# %% [markdown]
# ---
